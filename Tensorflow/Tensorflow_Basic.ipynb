# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishal-21x/Data-Science/blob/main/Tensorflow/Tensorflow_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **What's Covered**
#
# 1. Builing a Tenseorflow Chirn Model
# 2. Training and Predicting
# 3. Saving you rmodel and reloading

# %% [markdown]
# ### **0. Import Data**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Churn.csv')

# %%
X = pd.get_dummies(df.drop(['Churn', 'Customer ID'], axis=1))
y = df['Churn'].apply(lambda x:1 if x=='Yes' else 0)

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
y_train.head()
# Out:
# 6382    0
# 756     1
# 1165    0
# 3258    0
# 2866    0
# Name: Churn, dtype: int64

# %% [markdown]
# ### **1. Import Dependencies**

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### **2. Build and Compile Model**

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7500 - loss: 0.5122
# Epoch 2/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7714 - loss: 0.4905
# Epoch 3/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7753 - loss: 0.4828
# Epoch 4/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7787 - loss: 0.4814
# Epoch 5/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7789 - loss: 0.4789
# Epoch 6/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7778 - loss: 0.4746
# Epoch 7/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7776 - loss: 0.4727
# Epoch 8/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7755 - loss: 0.4710
# Epoch 9/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7794 - loss: 0.4687
# Epoch 10/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7815 - loss: 0.4673
# Epoch 11/200
# ...

# %%
y_hat = model.predict(X_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.8019872249822569

# %% [markdown]
# ### **4. Saving and Reloading**

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/tfmodel.keras')

# %%
del model

# %%
model = load_model('/content/drive/MyDrive/Colab Notebooks/tfmodel.keras')
